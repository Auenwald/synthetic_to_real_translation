# %%
import json
import numpy as np

def extract_mean_ious(json_path):
    # JSON laden
    with open(json_path, "r") as f:
        data = json.load(f)

    # Ergebnis-Dict vorbereiten
    result = {}
    for dataset, epochs in data.items():
        result[dataset] = {}
        for epoch, metrics in epochs.items():
            result[dataset][int(epoch)] = metrics["mean_iou"]
    return result


def print_mious(mean_ious):
    synthia_mious = []
    bdd_mious = []
    cityscapes_mious = []

    for dataset, epochs in mean_ious.items():
        for epoch in epochs.keys():
            if dataset.lower() == 'synthia':
                synthia_mious.append(epochs[epoch])
            elif dataset.lower() == 'cityscapes':
                cityscapes_mious.append(epochs[epoch])
            elif dataset.lower() == 'bdd':
                bdd_mious.append(epochs[epoch])


    synthia_mious = np.array(synthia_mious)
    bdd_mious = np.array(bdd_mious)
    cityscapes_mious = np.array(cityscapes_mious)

    idx_synthia_epoch = np.argmax(synthia_mious)

    cityscapes_cp_miou, bdd_cp_miou = cityscapes_mious[idx_synthia_epoch], bdd_mious[idx_synthia_epoch]
    cityscapes_m_miou, bdd_m_miou = np.mean(cityscapes_mious), np.mean(bdd_mious)
    cityscapes_max_miou, bdd_max_miou = np.max(cityscapes_mious), np.max(bdd_mious)
    cityscapes_var_miou, bdd_var_miou = np.var(cityscapes_mious), np.var(bdd_mious)

    print(f'Cityscapes mean mean IoU: {cityscapes_m_miou:.3f}, CP mIoU: {cityscapes_cp_miou:.3f}, max mIoU {cityscapes_max_miou:.3f}')
    print(f'BDD mean mean IoU: {bdd_m_miou:.3f}, CP mIoU: {bdd_cp_miou:.3f}, max mIoU {bdd_max_miou:.3f}')



'''
if __name__ == "__main__":
    path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_crossattention_rgb_and_lab_no_amp.json"
    mean_ious = extract_mean_ious(path)

    # Ausgabe
    for dataset, epochs in mean_ious.items():
        print(f"\n📊 {dataset.capitalize()}")
        for epoch in sorted(epochs.keys()):
            print(f"  Epoch {epoch:3d}: {epochs[epoch]:.3f}")
'''
# Out:
# '\nif __name__ == "__main__":\n    path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_crossattention_rgb_and_lab_no_amp.json"\n    mean_ious = extract_mean_ious(path)\n\n    # Ausgabe\n    for dataset, epochs in mean_ious.items():\n        print(f"\n📊 {dataset.capitalize()}")\n        for epoch in sorted(epochs.keys()):\n            print(f"  Epoch {epoch:3d}: {epochs[epoch]:.3f}")\n'

# %%
path = "./logs/synthia_to_cs_and_bdd_segformerb5_lr1e5_lr1e4_no_crossattention_baseline.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.367, CP mIoU: 46.715, max mIoU 46.770
# BDD mean mean IoU: 38.478, CP mIoU: 38.235, max mIoU 40.408

# %%
path = "./logs/synthia_to_cs_and_bdd_segformerb5_adamw_lr_1e05_decay_0995_baseline_seed1.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 44.895, CP mIoU: 45.287, max mIoU 46.971
# BDD mean mean IoU: 38.089, CP mIoU: 38.647, max mIoU 40.935

# %%
path = "./logs/synthia_to_cs_and_bdd_segformerb5_adamw_lr_1e05_decay_0995_baseline_seed2.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.069, CP mIoU: 44.769, max mIoU 46.369
# BDD mean mean IoU: 38.152, CP mIoU: 38.168, max mIoU 40.389

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_crossattention_rgb_and_edges_no_amp.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.041, CP mIoU: 45.462, max mIoU 46.821
# BDD mean mean IoU: 36.368, CP mIoU: 37.462, max mIoU 38.624

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_crossattention_rgb_and_lab_no_amp.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 44.669, CP mIoU: 46.443, max mIoU 46.883
# BDD mean mean IoU: 35.906, CP mIoU: 37.642, max mIoU 38.134

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_crossattention_rgb_and_dct_no_amp.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.339, CP mIoU: 45.836, max mIoU 47.282
# BDD mean mean IoU: 36.447, CP mIoU: 36.006, max mIoU 38.986

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_crossattention_rgb_and_hsv_no_amp.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 44.747, CP mIoU: 45.357, max mIoU 47.063
# BDD mean mean IoU: 36.903, CP mIoU: 36.235, max mIoU 40.717

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_crossattention_rgb_and_edges_skip_stage0.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 44.675, CP mIoU: 46.271, max mIoU 47.717
# BDD mean mean IoU: 36.269, CP mIoU: 35.945, max mIoU 40.043

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_crossattention_rgb_and_lab_no_amp_skip_stage0.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.413, CP mIoU: 47.076, max mIoU 47.611
# BDD mean mean IoU: 36.566, CP mIoU: 36.403, max mIoU 38.242

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_crossattention_rgb_and_dct_no_amp_skip_stage0.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 44.379, CP mIoU: 44.425, max mIoU 46.886
# BDD mean mean IoU: 35.947, CP mIoU: 35.287, max mIoU 39.328

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_crossattention_rgb_and_fft_no_amp.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.201, CP mIoU: 46.038, max mIoU 47.101
# BDD mean mean IoU: 36.486, CP mIoU: 36.283, max mIoU 39.353

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_crossattention_rgb_and_fft_no_amp_skip_stage0.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.146, CP mIoU: 45.938, max mIoU 46.876
# BDD mean mean IoU: 36.727, CP mIoU: 36.336, max mIoU 40.041

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_crossattention_rgb_and_hsv_no_amp_skip_stage0.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.435, CP mIoU: 46.655, max mIoU 47.122
# BDD mean mean IoU: 37.047, CP mIoU: 39.076, max mIoU 41.044

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_crossattention_rgb_and_fft_gating_conv_v2.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.510, CP mIoU: 45.912, max mIoU 47.416
# BDD mean mean IoU: 38.020, CP mIoU: 37.544, max mIoU 41.597

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_crossattention_rgb_and_dct_gating_conv_v2.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.448, CP mIoU: 46.784, max mIoU 47.668
# BDD mean mean IoU: 38.208, CP mIoU: 37.848, max mIoU 40.904

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_crossattention_rgb_and_edges_conv_v2.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.234, CP mIoU: 47.236, max mIoU 47.236
# BDD mean mean IoU: 37.930, CP mIoU: 39.726, max mIoU 41.285

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_crossattention_rgb_and_hsv_gating_conv_v2.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 44.595, CP mIoU: 46.143, max mIoU 46.830
# BDD mean mean IoU: 37.746, CP mIoU: 37.239, max mIoU 39.932

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_rgb_and_lab_conv_v2.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 44.853, CP mIoU: 45.519, max mIoU 47.238
# BDD mean mean IoU: 37.933, CP mIoU: 38.263, max mIoU 40.116

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_rgb_and_edges_conv_v2_seed1.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.393, CP mIoU: 45.973, max mIoU 47.824
# BDD mean mean IoU: 38.240, CP mIoU: 37.698, max mIoU 40.943

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_rgb_and_edges_conv_v2_seed2.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.292, CP mIoU: 45.456, max mIoU 46.643
# BDD mean mean IoU: 38.265, CP mIoU: 36.986, max mIoU 40.880

# %%
mious = np.array([47.24, 46.37, 47.82])
print(np.mean(mious), np.std(mious))
# Out:
# 47.14333333333334 0.5958933536203358

# %%
mious = np.array([47.24, 44.42, 45.46])
print(np.mean(mious), np.std(mious))
# Out:
# 45.70666666666667 1.1643977938068342

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_rgb_and_dct_convv2_seed1.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.053, CP mIoU: 45.983, max mIoU 47.631
# BDD mean mean IoU: 37.680, CP mIoU: 37.018, max mIoU 40.029

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_rgb_and_dct_convv2_seed2.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.104, CP mIoU: 44.825, max mIoU 47.133
# BDD mean mean IoU: 38.340, CP mIoU: 37.241, max mIoU 41.454

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_crossattention_rgb_and_fft_gating_conv_v2.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.510, CP mIoU: 45.912, max mIoU 47.416
# BDD mean mean IoU: 38.020, CP mIoU: 37.544, max mIoU 41.597

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_rgb_and_fft_convv2_seed1.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.801, CP mIoU: 46.471, max mIoU 47.292
# BDD mean mean IoU: 37.686, CP mIoU: 38.622, max mIoU 40.397

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_rgb_and_fft_convv2_seed2.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.540, CP mIoU: 46.146, max mIoU 47.291
# BDD mean mean IoU: 38.092, CP mIoU: 38.689, max mIoU 41.547

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_rgb_and_wavelets_convv2.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 46.082, CP mIoU: 45.628, max mIoU 47.563
# BDD mean mean IoU: 38.555, CP mIoU: 35.627, max mIoU 40.727

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_rgb_and_wavelets_convv2_seed1.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.448, CP mIoU: 46.493, max mIoU 47.429
# BDD mean mean IoU: 37.857, CP mIoU: 37.748, max mIoU 41.373

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_rgb_and_wavelets_convv2_seed2.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.681, CP mIoU: 46.378, max mIoU 47.738
# BDD mean mean IoU: 38.376, CP mIoU: 37.531, max mIoU 41.462

# %%
path = "./logs_final/synthia_to_cs_and_bdd_segformerb1_adamw_lr_1e05_decay_0995_baseline_seed0.txt"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 34.552, CP mIoU: 37.143, max mIoU 38.038
# BDD mean mean IoU: 26.577, CP mIoU: 27.412, max mIoU 28.753

# %%
path = "./logs_final/synthia_to_cs_and_bdd_segformerb1_adamw_lr_1e05_decay_0995_baseline_seed1.txt"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 33.847, CP mIoU: 38.195, max mIoU 38.419
# BDD mean mean IoU: 26.380, CP mIoU: 28.231, max mIoU 29.725

# %%
path = "./logs_final/synthia_to_cs_and_bdd_segformerb1_adamw_lr_1e05_decay_0995_baseline_seed2.txt"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 32.192, CP mIoU: 34.929, max mIoU 37.012
# BDD mean mean IoU: 26.102, CP mIoU: 25.954, max mIoU 28.310

# %%
path = "./logs_final/synthia_to_cs_and_bdd_segformerb1_adamw_lr_1e05_decay_0995_edges_convv2_seed0.txt"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 34.802, CP mIoU: 37.775, max mIoU 38.243
# BDD mean mean IoU: 26.340, CP mIoU: 27.075, max mIoU 28.300

# %%
path = "./logs_final/synthia_to_cs_and_bdd_segformerb1_adamw_lr_1e05_decay_0995_edges_convv2_seed1.txt"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 33.453, CP mIoU: 36.015, max mIoU 39.182
# BDD mean mean IoU: 26.483, CP mIoU: 26.051, max mIoU 28.476

# %%
path = "./logs_final/synthia_to_cs_and_bdd_segformerb1_adamw_lr_1e05_decay_0995_edges_convv2_seed2.txt"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 34.549, CP mIoU: 37.686, max mIoU 38.765
# BDD mean mean IoU: 26.733, CP mIoU: 28.839, max mIoU 28.839

# %%
path = "./logs_final/synthia_to_cs_and_bdd_segformerb1_adamw_lr_1e05_decay_0995_fft_convv2_seed0.txt"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 33.944, CP mIoU: 34.961, max mIoU 39.957
# BDD mean mean IoU: 26.414, CP mIoU: 25.471, max mIoU 30.478

# %%
path = "./logs_final/synthia_to_cs_and_bdd_segformerb1_adamw_lr_1e05_decay_0995_fft_convv2_seed1.txt"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 34.546, CP mIoU: 37.524, max mIoU 38.731
# BDD mean mean IoU: 26.271, CP mIoU: 26.179, max mIoU 28.331

# %%
path = "./logs_final/synthia_to_cs_and_bdd_segformerb1_adamw_lr_1e05_decay_0995_fft_convv2_seed2.txt"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 34.983, CP mIoU: 37.097, max mIoU 38.584
# BDD mean mean IoU: 26.863, CP mIoU: 26.873, max mIoU 29.509

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_crossattention_rgb_and_hsv_gating_conv_v2.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 44.595, CP mIoU: 46.143, max mIoU 46.830
# BDD mean mean IoU: 37.746, CP mIoU: 37.239, max mIoU 39.932

# %%
path = "./logs_final/synthia_to_cs_and_bdd_segformerb5_adamw_lr_1e05_hsv_convv2_seed1.txt"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 44.478, CP mIoU: 46.416, max mIoU 47.338
# BDD mean mean IoU: 37.211, CP mIoU: 38.327, max mIoU 40.423

# %%
path = "./logs_final/synthia_to_cs_and_bdd_segformerb5_adamw_lr_1e05_hsv_convv2_seed2.txt"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 44.972, CP mIoU: 44.530, max mIoU 47.060
# BDD mean mean IoU: 38.160, CP mIoU: 36.951, max mIoU 41.659

# %%
path = "./logs_final/synthia_to_cs_and_bdd_segformerb5_adamw_lr_1e05_lab_convv2_seed1.txt"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.013, CP mIoU: 45.388, max mIoU 47.338
# BDD mean mean IoU: 37.602, CP mIoU: 36.802, max mIoU 41.400

# %%
path = "./logs_final/synthia_to_cs_and_bdd_segformerb5_adamw_lr_1e05_lab_convv2_seed2.txt"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 45.805, CP mIoU: 46.336, max mIoU 47.758
# BDD mean mean IoU: 38.146, CP mIoU: 38.311, max mIoU 40.558

# %%
path = "./logs/synthia_to_cs_and_bdd_lr1e5_and_lr1e4_rgb_and_lab_conv_v2.json"
mean_ious = extract_mean_ious(path)
print_mious(mean_ious)
# Out:
# Cityscapes mean mean IoU: 44.853, CP mIoU: 45.519, max mIoU 47.238
# BDD mean mean IoU: 37.933, CP mIoU: 38.263, max mIoU 40.116
